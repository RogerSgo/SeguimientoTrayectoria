# %%
# Evaluacion con ciclo anidado, for - while
import gymnasium   #
import CoppeliaSim_Gym   # Entorno personalizado
import stable_baselines3   # Biblioteca RL
from stable_baselines3 import A2C, PPO
from matplotlib import pyplot as plt 
import pandas as pd
import numpy as np

# Inicializar el entorno
ENV_NAME = "CoppeliaSim_Gym/GymCoppManR-v0"
env = gymnasium.make(ENV_NAME)
model = A2C.load("best_model", env=env)
model.policy
val = []
X_ = []
Y_ = []
vx = []
vy = []
all_episode_rewards = []
num_episodes = 5
for i in range(num_episodes):
    episode_rewards = []
    done = False
    obs, info = env.reset()
    while not done:
        env.render()
        # states solo son útiles cuando se usan políticas LSTM
        action, states = model.predict(obs, deterministic=False)
        #
        px = env.get_posicion(env.target)[0]
        py = env.get_posicion(env.target)[1]
        vx.append(np.array(px))
        vy.append(np.array(py))
        # here, action, rewards and dones are arrays
        # because we are using vectorized env
        obs, reward, done, tru, info = env.step(action)
        episode_rewards.append(reward)
        val += [reward]
        X_.append(env.step_counter)
        Y_.append(np.array(val).mean())
        
    all_episode_rewards.append(sum(episode_rewards))
plt.plot(X_, Y_)
plt.grid()
plt.title('Acumulated reward')
plt.xlabel('Steps')
plt.ylabel('Reward')
plt.show()

env.grafica(vx, vy)
mean_episode_reward = np.mean(all_episode_rewards)
print("Mean reward:", mean_episode_reward, "Num episodes:", num_episodes)
env.close()
# Out:
# Conectado al servidor API remoto
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# --------------------------------------------------------------------
# STEP:  1
# Acciones:  [1.         1.         0.41105378]
# Angulos: Trayectoria: -2.377, Efector Final: -0.000
# RC: 0.247, RG: 0.822, RA: 0.603, RF: 0.000
# --- RECOMPENSA TOTAL: 1.672 ---
# --------------------------------------------------------------------
# STEP:  2
# Acciones:  [ 0.9723866 -1.        -1.       ]
# Angulos: Trayectoria: -2.068, Efector Final: 0.411
# RC: 0.248, RG: -2.000, RA: 0.257, RF: 0.000
# --- RECOMPENSA TOTAL: -1.495 ---
# --------------------------------------------------------------------
# STEP:  3
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 0.000, Efector Final: -0.589
# RC: 0.249, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.999 ---
# --------------------------------------------------------------------
# STEP:  4
# Acciones:  [1.        1.        0.7428043]
# Angulos: Trayectoria: -16.878, Efector Final: 0.411
# RC: 0.227, RG: 1.486, RA: 0.686, RF: 0.000
# --- RECOMPENSA TOTAL: 2.398 ---
# --------------------------------------------------------------------
# STEP:  5
# Acciones:  [ 1.        -1.        -0.8706261]
# Angulos: Trayectoria: -24.611, Efector Final: 1.154
# RC: 0.217, RG: -1.741, RA: 0.218, RF: 0.000
# --- RECOMPENSA TOTAL: -1.306 ---
# --------------------------------------------------------------------
# STEP:  6
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -37.163, Efector Final: 0.283
# RC: 0.199, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.949 ---
# --------------------------------------------------------------------
# STEP:  7
# Acciones:  [ 1.  1. -1.]
# Angulos: Trayectoria: -28.531, Efector Final: 1.283
# RC: 0.212, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.538 ---
# --------------------------------------------------------------------
# STEP:  8
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -25.996, Efector Final: 0.283
# RC: 0.214, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.964 ---
# --------------------------------------------------------------------
# STEP:  9
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -29.006, Efector Final: 1.283
# RC: 0.211, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.961 ---
# --------------------------------------------------------------------
# STEP:  10
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -38.090, Efector Final: 2.283
# RC: 0.200, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.950 ---
# --------------------------------------------------------------------
# STEP:  11
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -32.562, Efector Final: 3.283
# RC: 0.209, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.959 ---
# --------------------------------------------------------------------
# STEP:  12
# Acciones:  [ 1.         -0.37474823  0.82532144]
# Angulos: Trayectoria: -43.662, Efector Final: 4.283
# RC: 0.195, RG: 1.651, RA: 0.363, RF: 0.000
# --- RECOMPENSA TOTAL: 2.209 ---
# --------------------------------------------------------------------
# STEP:  13
# Acciones:  [ 1.          1.         -0.17627943]
# Angulos: Trayectoria: -35.191, Efector Final: 5.109
# RC: 0.208, RG: -0.353, RA: 0.456, RF: 0.000
# --- RECOMPENSA TOTAL: 0.312 ---
# --------------------------------------------------------------------
# STEP:  14
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -20.640, Efector Final: 4.932
# RC: 0.228, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.978 ---
# --------------------------------------------------------------------
# STEP:  15
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -3.861, Efector Final: 5.932
# RC: 0.247, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.997 ---
# --------------------------------------------------------------------
# STEP:  16
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -10.257, Efector Final: 6.932
# RC: 0.245, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.505 ---
# --------------------------------------------------------------------
# STEP:  17
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -9.027, Efector Final: 5.932
# RC: 0.246, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.996 ---
# --------------------------------------------------------------------
# STEP:  18
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 5.348, Efector Final: 6.932
# RC: 0.233, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.017 ---
# --------------------------------------------------------------------
# STEP:  19
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: 2.661, Efector Final: 7.932
# RC: 0.235, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.485 ---
# --------------------------------------------------------------------
# STEP:  20
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 12.773, Efector Final: 6.932
# RC: 0.223, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.027 ---
# --------------------------------------------------------------------
# STEP:  21
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: 25.419, Efector Final: 7.932
# RC: 0.204, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.454 ---
#  --- REINICIO ---
# --------------------------------------------------------------------
# STEP:  22
# Acciones:  [1.       1.       0.754282]
# Angulos: Trayectoria: 0.290, Efector Final: -0.000
# RC: 0.250, RG: -1.509, RA: 0.689, RF: 0.000
# --- RECOMPENSA TOTAL: -0.570 ---
# --------------------------------------------------------------------
# STEP:  23
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 2.048, Efector Final: 0.754
# RC: 0.246, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.004 ---
# --------------------------------------------------------------------
# STEP:  24
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 1.742, Efector Final: 1.754
# RC: 0.245, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.005 ---
# --------------------------------------------------------------------
# STEP:  25
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -4.625, Efector Final: 2.754
# RC: 0.247, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.503 ---
# --------------------------------------------------------------------
# STEP:  26
# Acciones:  [1.         1.         0.15430903]
# Angulos: Trayectoria: -12.402, Efector Final: 1.754
# RC: 0.235, RG: 0.309, RA: 0.539, RF: 0.000
# --- RECOMPENSA TOTAL: 1.082 ---
# --------------------------------------------------------------------
# STEP:  27
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -10.648, Efector Final: 1.909
# RC: 0.238, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.512 ---
# --------------------------------------------------------------------
# STEP:  28
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -27.699, Efector Final: 0.909
# RC: 0.213, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.963 ---
# --------------------------------------------------------------------
# STEP:  29
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -24.131, Efector Final: 1.909
# RC: 0.219, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.969 ---
# --------------------------------------------------------------------
# STEP:  30
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -38.656, Efector Final: 2.909
# RC: 0.200, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.950 ---
# --------------------------------------------------------------------
# STEP:  31
# Acciones:  [1.        1.        0.5136856]
# Angulos: Trayectoria: -50.350, Efector Final: 3.909
# RC: 0.185, RG: 1.027, RA: 0.628, RF: 0.000
# --- RECOMPENSA TOTAL: 1.841 ---
# --------------------------------------------------------------------
# STEP:  32
# Acciones:  [1.         1.         0.74954104]
# Angulos: Trayectoria: -53.515, Efector Final: 4.422
# RC: 0.182, RG: 1.499, RA: 0.687, RF: 0.000
# --- RECOMPENSA TOTAL: 2.368 ---
# --------------------------------------------------------------------
# STEP:  33
# Acciones:  [1.         1.         0.88000304]
# Angulos: Trayectoria: -17.629, Efector Final: 5.172
# RC: 0.233, RG: 1.760, RA: 0.720, RF: 0.000
# --- RECOMPENSA TOTAL: 2.713 ---
# --------------------------------------------------------------------
# STEP:  34
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -20.580, Efector Final: 6.052
# RC: 0.230, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.520 ---
# --------------------------------------------------------------------
# STEP:  35
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -9.743, Efector Final: 5.052
# RC: 0.243, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.993 ---
# --------------------------------------------------------------------
# STEP:  36
# Acciones:  [1.         1.         0.98524696]
# Angulos: Trayectoria: -27.929, Efector Final: 6.052
# RC: 0.220, RG: 1.970, RA: 0.746, RF: 0.000
# --- RECOMPENSA TOTAL: 2.936 ---
# --------------------------------------------------------------------
# STEP:  37
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 5.862, Efector Final: 7.037
# RC: 0.232, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.018 ---
# --------------------------------------------------------------------
# STEP:  38
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: 10.566, Efector Final: 8.037
# RC: 0.224, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.474 ---
# --------------------------------------------------------------------
# STEP:  39
# Acciones:  [ 0.8025054 -1.        -1.       ]
# Angulos: Trayectoria: 4.300, Efector Final: 7.037
# RC: 0.234, RG: 2.000, RA: 0.299, RF: 0.000
# --- RECOMPENSA TOTAL: 2.534 ---
# --------------------------------------------------------------------
# STEP:  40
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 25.348, Efector Final: 6.037
# RC: 0.206, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.044 ---
# --------------------------------------------------------------------
# STEP:  41
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: 32.854, Efector Final: 7.037
# RC: 0.195, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.445 ---
# --------------------------------------------------------------------
# STEP:  42
# Acciones:  [ 0.69224656 -1.         -1.        ]
# Angulos: Trayectoria: 3.127, Efector Final: 6.037
# RC: 0.237, RG: 2.000, RA: 0.327, RF: 0.000
# --- RECOMPENSA TOTAL: 2.564 ---
#  --- REINICIO ---
# --------------------------------------------------------------------
# STEP:  43
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 0.000, Efector Final: -0.000
# RC: 0.250, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.000 ---
# --------------------------------------------------------------------
# STEP:  44
# Acciones:  [1.         0.14131868 1.        ]
# Angulos: Trayectoria: 0.000, Efector Final: 1.000
# RC: 0.249, RG: 2.000, RA: 0.535, RF: 0.000
# --- RECOMPENSA TOTAL: 2.784 ---
# --------------------------------------------------------------------
# STEP:  45
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -5.085, Efector Final: 2.000
# RC: 0.246, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.504 ---
# --------------------------------------------------------------------
# STEP:  46
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 0.000, Efector Final: 1.000
# RC: 0.249, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.999 ---
# --------------------------------------------------------------------
# STEP:  47
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -14.740, Efector Final: 2.000
# RC: 0.232, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.982 ---
# --------------------------------------------------------------------
# STEP:  48
# Acciones:  [ 0.7724947 -1.        -1.       ]
# Angulos: Trayectoria: -36.334, Efector Final: 3.000
# RC: 0.204, RG: -2.000, RA: 0.307, RF: 0.000
# --- RECOMPENSA TOTAL: -1.489 ---
# --------------------------------------------------------------------
# STEP:  49
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -11.806, Efector Final: 2.000
# RC: 0.236, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.986 ---
# --------------------------------------------------------------------
# STEP:  50
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -49.104, Efector Final: 3.000
# RC: 0.186, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.936 ---
# --------------------------------------------------------------------
# STEP:  51
# Acciones:  [1.        1.        0.6051686]
# Angulos: Trayectoria: -48.209, Efector Final: 4.000
# RC: 0.189, RG: 1.210, RA: 0.651, RF: 0.000
# --- RECOMPENSA TOTAL: 2.050 ---
# --------------------------------------------------------------------
# STEP:  52
# Acciones:  [1.         1.         0.52818775]
# Angulos: Trayectoria: -49.449, Efector Final: 4.605
# RC: 0.188, RG: 1.056, RA: 0.632, RF: 0.000
# --- RECOMPENSA TOTAL: 1.876 ---
# --------------------------------------------------------------------
# STEP:  53
# Acciones:  [1.         1.         0.95917404]
# Angulos: Trayectoria: -36.657, Efector Final: 5.133
# RC: 0.206, RG: 1.918, RA: 0.740, RF: 0.000
# --- RECOMPENSA TOTAL: 2.864 ---
# --------------------------------------------------------------------
# STEP:  54
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -20.281, Efector Final: 6.093
# RC: 0.230, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.980 ---
# --------------------------------------------------------------------
# STEP:  55
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -23.144, Efector Final: 7.093
# RC: 0.228, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.522 ---
# --------------------------------------------------------------------
# STEP:  56
# Acciones:  [1.        0.9461175 1.       ]
# Angulos: Trayectoria: -9.506, Efector Final: 6.093
# RC: 0.245, RG: 2.000, RA: 0.737, RF: 0.000
# --- RECOMPENSA TOTAL: 2.982 ---
# --------------------------------------------------------------------
# STEP:  57
# Acciones:  [1.        1.        0.6055261]
# Angulos: Trayectoria: -25.461, Efector Final: 7.093
# RC: 0.224, RG: 1.211, RA: 0.651, RF: 0.000
# --- RECOMPENSA TOTAL: 2.087 ---
# --------------------------------------------------------------------
# STEP:  58
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 1.629, Efector Final: 7.698
# RC: 0.237, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.013 ---
# --------------------------------------------------------------------
# STEP:  59
# Acciones:  [ 0.01250494 -1.         -1.        ]
# Angulos: Trayectoria: -7.724, Efector Final: 8.698
# RC: 0.249, RG: -2.000, RA: 0.497, RF: 0.000
# --- RECOMPENSA TOTAL: -1.254 ---
# --------------------------------------------------------------------
# STEP:  60
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -0.223, Efector Final: 7.698
# RC: 0.240, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.990 ---
# --------------------------------------------------------------------
# STEP:  61
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 23.677, Efector Final: 8.698
# RC: 0.205, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.045 ---
# --------------------------------------------------------------------
# STEP:  62
# Acciones:  [ 0.66163605 -1.         -1.        ]
# Angulos: Trayectoria: 23.965, Efector Final: 9.698
# RC: 0.203, RG: 2.000, RA: 0.335, RF: 0.000
# --- RECOMPENSA TOTAL: 2.538 ---
# --------------------------------------------------------------------
# STEP:  63
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: 9.970, Efector Final: 8.698
# RC: 0.224, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.474 ---
# --------------------------------------------------------------------
# STEP:  64
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 16.176, Efector Final: 7.698
# RC: 0.217, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.033 ---
# --------------------------------------------------------------------
# STEP:  65
# Acciones:  [ 0.6413355  -1.          0.40901628]
# Angulos: Trayectoria: 20.358, Efector Final: 8.698
# RC: 0.210, RG: -0.818, RA: 0.013, RF: 0.000
# --- RECOMPENSA TOTAL: -0.596 ---
# --------------------------------------------------------------------
# STEP:  66
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 44.759, Efector Final: 9.107
# RC: 0.175, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.075 ---
# --------------------------------------------------------------------
# STEP:  67
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: 56.542, Efector Final: 10.107
# RC: 0.157, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.407 ---
# --------------------------------------------------------------------
# STEP:  68
# Acciones:  [ 1.       -1.       -0.653146]
# Angulos: Trayectoria: 56.172, Efector Final: 9.107
# RC: 0.159, RG: 1.306, RA: 0.163, RF: 0.000
# --- RECOMPENSA TOTAL: 1.629 ---
#  --- REINICIO ---
# --------------------------------------------------------------------
# STEP:  69
# Acciones:  [1.         0.92120516 1.        ]
# Angulos: Trayectoria: 0.000, Efector Final: -0.000
# RC: 0.250, RG: -2.000, RA: 0.730, RF: 0.000
# --- RECOMPENSA TOTAL: -1.020 ---
# --------------------------------------------------------------------
# STEP:  70
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 1.998, Efector Final: 1.000
# RC: 0.246, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.004 ---
# --------------------------------------------------------------------
# STEP:  71
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -2.808, Efector Final: 2.000
# RC: 0.249, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.999 ---
# --------------------------------------------------------------------
# STEP:  72
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -2.881, Efector Final: 3.000
# RC: 0.250, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.500 ---
# --------------------------------------------------------------------
# STEP:  73
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 0.000, Efector Final: 2.000
# RC: 0.247, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.997 ---
# --------------------------------------------------------------------
# STEP:  74
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -4.134, Efector Final: 3.000
# RC: 0.248, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.998 ---
# --------------------------------------------------------------------
# STEP:  75
# Acciones:  [-0.23681831 -1.         -0.7332758 ]
# Angulos: Trayectoria: -34.232, Efector Final: 4.000
# RC: 0.208, RG: -1.467, RA: 0.493, RF: 0.000
# --- RECOMPENSA TOTAL: -0.766 ---
# --------------------------------------------------------------------
# STEP:  76
# Acciones:  [-0.12063289 -1.         -1.        ]
# Angulos: Trayectoria: -19.128, Efector Final: 3.267
# RC: 0.228, RG: -2.000, RA: 0.530, RF: 0.000
# --- RECOMPENSA TOTAL: -1.242 ---
# --------------------------------------------------------------------
# STEP:  77
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -35.949, Efector Final: 2.267
# RC: 0.203, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.953 ---
# --------------------------------------------------------------------
# STEP:  78
# Acciones:  [ 0.44960028 -0.9030309  -0.43687892]
# Angulos: Trayectoria: -16.583, Efector Final: 3.267
# RC: 0.232, RG: -0.874, RA: 0.223, RF: 0.000
# --- RECOMPENSA TOTAL: -0.420 ---
# --------------------------------------------------------------------
# STEP:  79
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -39.884, Efector Final: 2.830
# RC: 0.199, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.949 ---
# --------------------------------------------------------------------
# STEP:  80
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -51.861, Efector Final: 3.830
# RC: 0.183, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.933 ---
# --------------------------------------------------------------------
# STEP:  81
# Acciones:  [1.         1.         0.76421785]
# Angulos: Trayectoria: -50.920, Efector Final: 4.830
# RC: 0.186, RG: 1.528, RA: 0.691, RF: 0.000
# --- RECOMPENSA TOTAL: 2.405 ---
# --------------------------------------------------------------------
# STEP:  82
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -48.791, Efector Final: 5.594
# RC: 0.190, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.940 ---
# --------------------------------------------------------------------
# STEP:  83
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -27.716, Efector Final: 6.594
# RC: 0.221, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.971 ---
# --------------------------------------------------------------------
# STEP:  84
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -29.342, Efector Final: 7.594
# RC: 0.220, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.970 ---
# --------------------------------------------------------------------
# STEP:  85
# Acciones:  [1.        1.        0.9982637]
# Angulos: Trayectoria: 2.174, Efector Final: 8.594
# RC: 0.235, RG: -1.997, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.012 ---
# --------------------------------------------------------------------
# STEP:  86
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -13.782, Efector Final: 9.592
# RC: 0.244, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.506 ---
# --------------------------------------------------------------------
# STEP:  87
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -0.186, Efector Final: 8.592
# RC: 0.238, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.988 ---
# --------------------------------------------------------------------
# STEP:  88
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 3.215, Efector Final: 9.592
# RC: 0.232, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.018 ---
# --------------------------------------------------------------------
# STEP:  89
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 12.871, Efector Final: 10.592
# RC: 0.217, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.033 ---
# --------------------------------------------------------------------
# STEP:  90
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: 10.925, Efector Final: 11.592
# RC: 0.219, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.469 ---
# --------------------------------------------------------------------
# STEP:  91
# Acciones:  [1.       1.       0.792271]
# Angulos: Trayectoria: 15.465, Efector Final: 10.592
# RC: 0.214, RG: -1.585, RA: 0.698, RF: 0.000
# --- RECOMPENSA TOTAL: -0.673 ---
# --------------------------------------------------------------------
# STEP:  92
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: 17.806, Efector Final: 11.385
# RC: 0.209, RG: 2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: 2.459 ---
# --------------------------------------------------------------------
# STEP:  93
# Acciones:  [1.        0.7247946 1.       ]
# Angulos: Trayectoria: 34.212, Efector Final: 10.385
# RC: 0.188, RG: -2.000, RA: 0.681, RF: 0.000
# --- RECOMPENSA TOTAL: -1.131 ---
# --------------------------------------------------------------------
# STEP:  94
# Acciones:  [-0.54072094 -1.         -1.        ]
# Angulos: Trayectoria: 47.411, Efector Final: 11.385
# RC: 0.168, RG: 2.000, RA: 0.635, RF: 0.000
# --- RECOMPENSA TOTAL: 2.804 ---
# --------------------------------------------------------------------
# STEP:  95
# Acciones:  [ 0.19926703 -1.         -1.        ]
# Angulos: Trayectoria: 42.846, Efector Final: 10.385
# RC: 0.176, RG: 2.000, RA: 0.450, RF: 0.000
# --- RECOMPENSA TOTAL: 2.626 ---
# --------------------------------------------------------------------
# STEP:  96
# Acciones:  [ 0.02349353 -1.         -1.        ]
# Angulos: Trayectoria: 7.501, Efector Final: 9.385
# RC: 0.227, RG: 2.000, RA: 0.494, RF: 0.000
# --- RECOMPENSA TOTAL: 2.721 ---
#  --- REINICIO ---
# --------------------------------------------------------------------
# STEP:  97
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 0.289, Efector Final: -0.000
# RC: 0.250, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.000 ---
# --------------------------------------------------------------------
# STEP:  98
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -2.414, Efector Final: 1.000
# RC: 0.248, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.998 ---
# --------------------------------------------------------------------
# STEP:  99
# Acciones:  [-0.09164429 -1.         -1.        ]
# Angulos: Trayectoria: 0.930, Efector Final: 2.000
# RC: 0.246, RG: 2.000, RA: 0.523, RF: 0.000
# --- RECOMPENSA TOTAL: 2.769 ---
# --------------------------------------------------------------------
# STEP:  100
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -7.205, Efector Final: 1.000
# RC: 0.241, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.991 ---
# --------------------------------------------------------------------
# STEP:  101
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -0.764, Efector Final: 2.000
# RC: 0.248, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.502 ---
# --------------------------------------------------------------------
# STEP:  102
# Acciones:  [ 1.         1.        -0.2935027]
# Angulos: Trayectoria: -15.714, Efector Final: 1.000
# RC: 0.230, RG: -0.587, RA: 0.427, RF: 0.000
# --- RECOMPENSA TOTAL: 0.069 ---
# --------------------------------------------------------------------
# STEP:  103
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -14.360, Efector Final: 0.706
# RC: 0.231, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.981 ---
# --------------------------------------------------------------------
# STEP:  104
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -29.276, Efector Final: 1.706
# RC: 0.212, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.962 ---
# --------------------------------------------------------------------
# STEP:  105
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -23.553, Efector Final: 2.706
# RC: 0.221, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.529 ---
# --------------------------------------------------------------------
# STEP:  106
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -52.112, Efector Final: 1.706
# RC: 0.180, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.930 ---
# --------------------------------------------------------------------
# STEP:  107
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -43.494, Efector Final: 2.706
# RC: 0.193, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.943 ---
# --------------------------------------------------------------------
# STEP:  108
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -52.481, Efector Final: 3.706
# RC: 0.182, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.932 ---
# --------------------------------------------------------------------
# STEP:  109
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -22.168, Efector Final: 4.706
# RC: 0.226, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.976 ---
# --------------------------------------------------------------------
# STEP:  110
# Acciones:  [1.        0.8521489 1.       ]
# Angulos: Trayectoria: -47.558, Efector Final: 5.706
# RC: 0.192, RG: 2.000, RA: 0.713, RF: 0.000
# --- RECOMPENSA TOTAL: 2.905 ---
# --------------------------------------------------------------------
# STEP:  111
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: -1.466, Efector Final: 6.706
# RC: 0.243, RG: 2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: 2.993 ---
# --------------------------------------------------------------------
# STEP:  112
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -2.166, Efector Final: 7.706
# RC: 0.242, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.508 ---
# --------------------------------------------------------------------
# STEP:  113
# Acciones:  [1. 1. 1.]
# Angulos: Trayectoria: 4.629, Efector Final: 6.706
# RC: 0.234, RG: -2.000, RA: 0.750, RF: 0.000
# --- RECOMPENSA TOTAL: -1.016 ---
# --------------------------------------------------------------------
# STEP:  114
# Acciones:  [ 1. -1. -1.]
# Angulos: Trayectoria: -9.251, Efector Final: 7.706
# RC: 0.248, RG: -2.000, RA: 0.250, RF: 0.000
# --- RECOMPENSA TOTAL: -1.502 ---
#  --- REINICIO ---
# Mean reward: 28.267491830232547 Num episodes: 5
